# %%
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
# dataset have?
import pandas as pd
df=pd.read_excel("flight_price.xlsx")
df.shape
"""The dataset has 10683 rows and 11 columns """
# Out:
# 'The dataset has 10683 rows and 11 columns '

# %%
# Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
# distribution.
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(x='Price',data=df,kde=True)
plt.show()

# %%
# Q3. What is the range of prices in the dataset? What is the minimum and maximum price?
max_price = df["Price"].max()
min_price = df["Price"].min()

# %%
max_price,min_price
# Out:
# (79512, 1759)

# %%
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.

import seaborn as sns
import matplotlib.pyplot as plt
plt.subplots(figsize=(15,10))
sns.boxplot(y="Price", x="Airline",data=df)
plt.show()

# %%
df["Airline"].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
import plotly.express as px
fig = px.box(df, x="Airline", y="Price", height=600, width=1000)
fig.show()

# %%
"""obsevations :(1) lowest price ticket is of spicejet,highest price ticket is jet airways business
(2)median salary of indigo ,goair,airasia is approximately same
"""
# Out:
# 8372.0

# %%
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.

import seaborn as sns
import matplotlib.pyplot as plt

plt.subplots(figsize=(10,6))
sns.boxplot(x=df["Price"])
plt.show()

# %%
"""outliers are the data point that are outside the 1.5 times of the interquartile range there are many data points
that we can see in the boxplot that are outside this range .Based on the boxplot, it appears that there are several 
potential outliers in the "Price" column. Outliers are defined as data points that fall outside the whiskers of the 
boxplot, which are calculated as 1.5 times the interquartile range  above the third quartile  and below the
 first quartile .

The points outside this range may be due to fluctuations , or unssen events . All of these will make calculation 
where there may be anomalies.
 
 
  these potential outliers are errors or anomalies in the data, they could impact the accuracy of
   any statistical analysis performed on the dataset. Therefore, it's important to carefully consider any potential 
   outliers and determine whether they are genuine data points . If they are determined to be anomalies,
     they may need to be removed from the dataset before any further analysis is performed."""

import pandas as pd


Q1 = df['Price'].quantile(0.25)
Q3 = df['Price'].quantile(0.75)
IQR = Q3 - Q1
df_filtered = df[(df['Price'] >= Q1 - 1.5*IQR) & (df['Price'] <= Q3 + 1.5*IQR)]

import plotly.express as px
fig = px.box(df_filtered, x="Airline", y="Price", height=600, width=1000)
fig.show()

# %%
# Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
# to identify the peak travel season. What features would you analyze to identify the peak season, and how
# would you present your findings to your boss?

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_excel("flight_price.xlsx")
df["Date_of_Journey"] = pd.to_datetime(df["Date_of_Journey"])
df["Month"] = df["Date_of_Journey"].dt.month
df["Month_Name"] = df["Month"].apply(lambda x: calendar.month_name[x])
df_final = pd.DataFrame({"Month_Name": df["Month_Name"], "Price": df["Price"]})
df_final = df_final.groupby("Month_Name")["Price"].sum().reset_index()
plt.pie(df_final["Price"], labels=df_final["Month_Name"], autopct="%1.1f%%")
plt.axis("equal")
plt.show()

"""THE PEAK SEASON IS MARCH,MAY,JUNE and in these three months approx 65 percent revenue is earned by the company"""
# Out:
# C:\Users\mukka\AppData\Local\Temp\ipykernel_5024\1561020905.py:6: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.

# %%
# Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
# Price dataset to identify any trends in flight prices. What features would you analyze to identify these
# trends, and what visualizations would you use to present your findings to your team?
# Line charts: To visualize the trends in flight prices over time or by departure time.

import pandas as pd
flight_df=pd.read_excel("flight_price.xlsx")
flight_df.info()
flight_df.describe
flight_df.isnull().head()
flight_df.isnull().sum()
flight_df.dropna(inplace = True)
flight_df[flight_df.duplicated()].head()
flight_df.drop_duplicates(keep='first',inplace=True)
flight_df.head()
flight_df["Route"].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB
# array(['BLR → DEL', 'CCU → IXR → BBI → BLR', 'DEL → LKO → BOM → COK',
#        'CCU → NAG → BLR', 'BLR → NAG → DEL', 'CCU → BLR',
#        'BLR → BOM → DEL', 'DEL → BOM → COK', 'DEL → BLR → COK',
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.catplot(y = "Price", x = "Airline", data = flight_df, kind="box", height = 4, aspect = 5)
plt.show()

"""jet airways has most outliers in terms of price """
# Out:
# 'jet airways has most outliers in terms of price '

# %%
sns.catplot(y = "Price", x = "Destination", data = flight_df.sort_values("Price", ascending = False), kind="box", height = 4, aspect = 3)
plt.show()

# %%
"""new delhi has most outliers and kolkata has least outliers"""

# %%
flight_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
flight_df["month"]=flight_df["Date_of_Journey"].str.split("/").str[1]

# %%
ax=sns.countplot(x="month",data=flight_df)
plt.show()

# %%
flight_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price month
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897    03
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    05
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    06
# 3    18:05         23:30   5h 25m      1 stop         No info   6218    05
# 4    16:50         21:35   4h 45m      1 stop         No info  13302    03

# %%
"""OBSERVATION- may has the largest number of flights  and the april has least number of flights """

# %%
plt.figure(figsize = (25,5))
plt.xlabel('Airline company')
plt.ylabel('number  of flights')
ax=sns.countplot(x = 'Airline', data =flight_df)

# %%
"""jet airways has highest no of flightd followed by IndiGo and AirIndia"""

# %%
# Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
# Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
# identify these factors, and how would you present your findings to the management team?

import pandas as pd 
flight_df=pd.read_excel("flight_price.xlsx")
flight_df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
flight_df["month"]=flight_df["Date_of_Journey"].str.split("/").str[1].astype(int)
flight_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  month  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897      3
# 1    05:50         13:15   7h 25m     2 stops         No info   7662      5
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882      6
# 3    18:05         23:30   5h 25m      1 stop         No info   6218      5
# 4    16:50         21:35   4h 45m      1 stop         No info  13302      3
#
#    year  duration_min
# 0  2019           170
# ...

# %%
flight_df["year"]=flight_df["Date_of_Journey"].str.split("/").str[2].astype(int)
flight_df.drop(["Date_of_Journey"],axis=1)
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price  month  year  \
# ...

# %%
flight_df["duration_min"]=flight_df["Duration"].str.replace("h","*60").str.replace(" ","+").str.replace("m","*1").apply(eval)

# %%
flight_df=flight_df.drop(["duratione"],axis=1)

# %%
flight_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  month  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897      3
# 1    05:50         13:15   7h 25m     2 stops         No info   7662      5
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882      6
# 3    18:05         23:30   5h 25m      1 stop         No info   6218      5
# 4    16:50         21:35   4h 45m      1 stop         No info  13302      3
#
#    year  duration_min
# 0  2019           170
# ...

# %%
flight_df.info()
flight_df.head()
flight_df=flight_df.drop(["year"],axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Arrival_Time     10683 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10682 non-null  object
#  8   Additional_Info  10683 non-null  object
#  9   Price            10683 non-null  int64
#  10  month            10683 non-null  int32
#  11  year             10683 non-null  int32
#  12  duration_min     10683 non-null  int64
#  13  Dep_hour         10683 non-null  int64
#  14  Dep_min          10683 non-null  int64
# dtypes: int32(2), int64(4), object(9)
# memory usage: 1.1+ MB

# %%
flight_df["Dep_hour"] = pd.to_datetime(flight_df["Dep_Time"]).dt.hour
flight_df["Dep_min"] = pd.to_datetime(flight_df["Dep_Time"]).dt.minute
flight_df.drop(["Dep_Time"], axis = 1, inplace = True)

# %%
plt.figure(figsize = (10,7))
sns.heatmap(flight_df.corr(), annot = True)
plt.show()
# Out:
# C:\Users\mukka\AppData\Local\Temp\ipykernel_5024\4111067471.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
"""FROM THE ABOVE CORRELATION CHART WE CAN SAY THAT FLIGHT PRICE IS MOST POSITIVELY CORRELATED TO THE DURATION 
WITH THE CORRELATION VALUE OF 0.51"""

# %%
# Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
# the dataset have?


df=pd.read_csv('googleplaystore.csv')
df.shape

"""it has 10841 rows and 13 columns"""
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
# app categories.

sns.catplot(x="Category",y="Rating",data=df.sort_values("Rating",ascending=True),kind="box",height=4,aspect=5)

# %%
df=df.groupby("Category")["Rating"].mean().reset_index()

# %%
df
# Out:
#                Category     Rating
# 0                   1.9  19.000000
# 1        ART_AND_DESIGN   4.358065
# 2     AUTO_AND_VEHICLES   4.190411
# 3                BEAUTY   4.278571
# 4   BOOKS_AND_REFERENCE   4.346067
# 5              BUSINESS   4.121452
# 6                COMICS   4.155172
# 7         COMMUNICATION   4.158537
# 8                DATING   3.970769
# 9             EDUCATION   4.389032
# 10        ENTERTAINMENT   4.126174
# 11               EVENTS   4.435556
# 12               FAMILY   4.192272
# 13              FINANCE   4.131889
# 14       FOOD_AND_DRINK   4.166972
# 15                 GAME   4.286326
# 16   HEALTH_AND_FITNESS   4.277104
# 17       HOUSE_AND_HOME   4.197368
# 18   LIBRARIES_AND_DEMO   4.178462
# 19            LIFESTYLE   4.094904
# 20  MAPS_AND_NAVIGATION   4.051613
# 21              MEDICAL   4.189143
# 22   NEWS_AND_MAGAZINES   4.132189
# 23            PARENTING   4.300000
# 24      PERSONALIZATION   4.335987
# 25          PHOTOGRAPHY   4.192114
# ...

# %%
# Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.
df=pd.read_csv('googleplaystore.csv')
df.isnull().sum()

""" missing values can have a significant impact on the analysis, as they can result in biased
  or incomplete results.  they may impact the statistical power, accuracy, and validity of the analysis. If missing 
  values are not handled appropriately, they may introduce errors,
   reduce the sample size, or lead to inaccurate conclusions. It is important to identify and handle missing values
    appropriately by imputing them or excluding them from the analysis."""
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
# the relationship.
df=pd.read_csv('googleplaystore.csv')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df["Size"].str.replace("Varies with device"," ")
# Out:
# 0         19M
# 1         14M
# 2        8.7M
# 3         25M
# 4        2.8M
#          ...
# 10836     53M
# 10837    3.6M
# 10838    9.5M
# 10839
# 10840     19M
# Name: Size, Length: 10841, dtype: object

# %%
df["Size"]=df["Size"].str.replace("M"," ")

# %%
sns.scatterplot(x="Size",y="Rating",data=df)
# Out:
# <Axes: xlabel='Size', ylabel='Rating'>

# %%
# Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.
df=pd.read_csv('googleplaystore.csv')

# %%
df["Price"] = df["Price"].str.replace("Everyone", "NaN")
df.dropna(subset=["Price"], inplace=True)

# %%
df["Price"] = df["Price"].str.replace("$", "")
df["Price"] = df["Price"].str.replace(" ","1")
df["Price"]=df["Price"].astype(float)
# Out:
# C:\Users\mukka\AppData\Local\Temp\ipykernel_5024\4245848894.py:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
df=df.groupby("Category")["Price"].mean().reset_index()

# %%
df.dropna()
# Out:
#                Category     Price
# 1        ART_AND_DESIGN  0.091846
# 2     AUTO_AND_VEHICLES  0.158471
# 3                BEAUTY  0.000000
# 4   BOOKS_AND_REFERENCE  0.518485
# 5              BUSINESS  0.402761
# 6                COMICS  0.000000
# 7         COMMUNICATION  0.214832
# 8                DATING  0.134316
# 9             EDUCATION  0.115128
# 10        ENTERTAINMENT  0.053557
# 11               EVENTS  1.718594
# 12               FAMILY  1.234675
# 13              FINANCE  7.925765
# 14       FOOD_AND_DRINK  0.066772
# 15                 GAME  0.251136
# 16   HEALTH_AND_FITNESS  0.197478
# 17       HOUSE_AND_HOME  0.000000
# 18   LIBRARIES_AND_DEMO  0.011647
# 19            LIFESTYLE  6.180288
# 20  MAPS_AND_NAVIGATION  0.196715
# 21              MEDICAL  3.110065
# 22   NEWS_AND_MAGAZINES  0.014064
# 23            PARENTING  0.159667
# 24      PERSONALIZATION  0.392755
# 25          PHOTOGRAPHY  0.400627
# 26         PRODUCTIVITY  0.591816
# ...

# %%
import seaborn as sns

sns.catplot(x="Category", y="Price", data=df, kind="bar")

# %%
import plotly.express as px

fig = px.bar(df, x="Category", y="Price")
fig.show()

# %%
# Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
# with the highest number of installs.


import pandas as pd
df = pd.read_csv("googleplaystore.csv")
freq_table = df.groupby("App")["Installs"].sum().reset_index()
top_10_apps = freq_table.sort_values("Installs", ascending=False).head(10)

print(top_10_apps)
# Out:
#                                               App  \
# 5806      Life Made WI-Fi Touchscreen Photo Frame
# 2364                             Candy Crush Saga
# 8304                                 Temple Run 2
# 8816                              Viber Messenger
# 7890                                     Snapchat
# 9508                imo free video calls and chat
# 7116                                          Pou
# 8673  UC Browser - Fast Download Private & Secure
# 5672                  LINE: Free Calls & Messages
# 5978                                    MX Player
#
#                                                Installs
# 5806                                               Free
# 2364  500,000,000+500,000,000+500,000,000+500,000,00...
# 8304  500,000,000+500,000,000+500,000,000+500,000,00...
# 8816  500,000,000+500,000,000+500,000,000+500,000,00...
# 7890   500,000,000+500,000,000+500,000,000+500,000,000+
# 9508   500,000,000+500,000,000+500,000,000+500,000,000+
# ...

# %%
# Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
# Google Playstore dataset to identify the most popular app categories. How would you approach this
# task, and what features would you analyze to make recommendations to the company?

"""
collect and preprocess the data , i will clean the data .

explore the data---> eda analysis is used to explore the data .

for analyzing the data following features would be looked into it.

(1)number of installs will give information about famous apps in the category

(2)user rating will give information about the choice of custoers


(3)price vs installs will give scenario for the maximum revenue.

overall the approch is to understand the beneath pattern and recommend the company 

"""

# %%
# Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
# most successful app developers. What features would you analyze to make recommendations to the
# company, and what data visualizations would you use to present your findings?
"""

I would analyze the number of installs for each app developer to identify the developers with
the highest number of installs. 

 I would analyze the average rating for each app developer to identify the developers 
with the highest user satisfaction. 

 I would analyze the number of apps developed by each developer to identify the most prolific 
developers.  

To present my findings, I would use the following data visualizations:

A bar chart can be used to visualize the number of installs for each app developer. This can 
be sorted in descending order to easily identify the developers with the highest number of installs.

 A scatter plot can be used to visualize the relationship between the average rating and the 
number of installs for each app developer. This can help identify the developers with the highest user 
satisfaction and popularity among users.

 A pie chart can be used to visualize the distribution of the number of apps developed by each developer. 
This can help identify the most prolific developers.






"""

# %%
# Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
# launch a new app. What features would you analyze to make recommendations to the company, and
# what data visualizations would you use to present your findings?

"""

By analyzing the monthly or yearly trends in app downloads, we can 
identify the months or seasons when app downloads are highest. This can help us determine the best time to launch a new app.

Different app categories may have different trends in app downloads, so we would need to analyze
 the trends for the specific app category of the new app.

 We would want to ensure that the new app receives high user ratings, so we would analyze 
user ratings for similar apps in the same category.



 A line chart can be used to visualize the monthly or yearly trends in app downloads for the 
specific app category. This can help identify the months or seasons when app downloads are highest.

 A bar chart can be used to visualize the number of app downloads for each app in the same category 
as the new app. This can help identify the most successful apps in the category and analyze their user ratings.

A scatter plot can be used to visualize the relationship between the user ratings and the number 
of downloads for similar apps in the same category. This can help identify any patterns in user ratings and 




"""
